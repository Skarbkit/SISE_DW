# %%
import pandas as pd
comptage = pd.read_csv('comptage-velo-donnees-compteurs.csv', sep=";")

# %%
comptage.head()
# Out:
#   Identifiant du compteur                    Nom du compteur  \
# 0     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 1     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 2     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 3     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 4     100003096-353242251  97 avenue Denfert Rochereau SO-NE
#
#    Identifiant du site de comptage      Nom du site de comptage  \
# 0                        100003096  97 avenue Denfert Rochereau
# 1                        100003096  97 avenue Denfert Rochereau
# 2                        100003096  97 avenue Denfert Rochereau
# 3                        100003096  97 avenue Denfert Rochereau
# 4                        100003096  97 avenue Denfert Rochereau
#
#    Comptage horaire  Date et heure de comptage  \
# 0               3.0  2021-10-01T03:00:00+02:00
# 1              91.0  2021-10-01T07:00:00+02:00
# 2               3.0  2021-10-01T05:00:00+02:00
# ...

# %%
comptage['jour mois annee comptage'] = comptage['Date et heure de comptage'].str.slice(stop=10)

# %%
comptage =comptage.drop(columns=['Date d\'installation du site de comptage','Lien vers photo du site de comptage','Identifiant technique compteur','ID Photos','test_lien_vers_photos_du_site_de_comptage_','id_photo_1','url_sites','type_dimage','Nom du compteur'])

# %%
import numpy as np
len(np.unique(comptage['Identifiant du site de comptage']))
# Out:
# 72

# %%
comptage.head()
# Out:
#   Identifiant du compteur  Identifiant du site de comptage  \
# 0     100003096-353242251                        100003096
# 1     100003096-353242251                        100003096
# 2     100003096-353242251                        100003096
# 3     100003096-353242251                        100003096
# 4     100003096-353242251                        100003096
#
#        Nom du site de comptage  Comptage horaire  Date et heure de comptage  \
# 0  97 avenue Denfert Rochereau               3.0  2021-10-01T03:00:00+02:00
# 1  97 avenue Denfert Rochereau              91.0  2021-10-01T07:00:00+02:00
# 2  97 avenue Denfert Rochereau               3.0  2021-10-01T05:00:00+02:00
# 3  97 avenue Denfert Rochereau               1.0  2021-10-01T04:00:00+02:00
# 4  97 avenue Denfert Rochereau             253.0  2021-10-01T08:00:00+02:00
#
#   Coordonnées géographiques mois_annee_comptage jour mois annee comptage
# 0          48.83504,2.33314             2021-10               2021-10-01
# ...

# %%
compression_opts = dict(method='zip',
                        archive_name='comptage.csv')

comptage.to_csv('comptage.zip', index=False,
          compression=compression_opts)
