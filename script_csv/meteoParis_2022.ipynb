# %%
import pandas as pd
import numpy as np
import os

# %%
rep="/Volumes/USB FLO/"
os.chdir(rep)

# %%
temp = pd.read_csv("donnees-synop-essentielles-omm.csv", sep=";")

# %%
temp.shape
# Out:
# (2174181, 82)

# %%
temp.dropna(0,'all')
# Out:
# /var/folders/bn/wmnlmrqn173_fl00j17x5hqm0000gn/T/ipykernel_20886/4073771236.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   temp.dropna(0,'all')
#          ID OMM station                       Date  Pression au niveau mer  \
# 0                  7558  2010-01-05T10:00:00+01:00                100280.0
# 1                 61976  2010-01-05T10:00:00+01:00                100990.0
# 2                  7027  2010-01-05T13:00:00+01:00                100720.0
# 3                  7110  2010-01-05T13:00:00+01:00                100750.0
# 4                  7591  2010-01-05T13:00:00+01:00                     NaN
# ...                 ...                        ...                     ...
# 2174176            7149  2021-04-23T05:00:00+02:00                102600.0
# 2174177            7255  2021-04-23T05:00:00+02:00                102310.0
# 2174178           71805  2021-04-23T08:00:00+02:00                100330.0
# 2174179           61972  2021-04-23T11:00:00+02:00                101470.0
# 2174180           81401  2021-04-23T11:00:00+02:00                101110.0
#
#          Variation de pression en 3 heures  Type de tendance barométrique  \
# 0                                    -50.0                            5.0
# 1                                      NaN                            NaN
# 2                                   -190.0                            8.0
# 3                                   -230.0                            8.0
# 4                                      NaN                            NaN
# ...                                    ...                            ...
# 2174176                               50.0                            3.0
# 2174177                               10.0                            3.0
# 2174178                               90.0                            1.0
# 2174179                               90.0                            8.0
# 2174180                               80.0                            3.0
#
#          Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  \
# 0                                260.0                          1.5
# 1                                  NaN                          NaN
# 2                                200.0                          3.6
# 3                                210.0                          4.1
# 4                                  NaN                          NaN
# ...                                ...                          ...
# 2174176                           60.0                          3.4
# 2174177                          120.0                          1.2
# 2174178                          210.0                         10.5
# 2174179                          180.0                          6.7
# 2174180                            0.0                          0.0
#
#          Température  Point de rosée  Humidité  ...  Altitude  \
# 0             275.75          275.75     100.0  ...       712
# 1             305.45          299.05      69.0  ...         7
# 2             273.65          271.75      87.0  ...        67
# 3             276.95          272.55      73.0  ...        94
# 4             274.45          269.05      67.0  ...       871
# ...              ...             ...       ...  ...       ...
# 2174176       279.75          273.25      63.0  ...        89
# 2174177       280.35          272.65      58.0  ...       161
# 2174178       275.45          272.15      79.0  ...        21
# 2174179       300.35          292.65      63.0  ...         6
# 2174180       296.55          296.25      98.0  ...         5
#
#                        communes (name)  communes (code)  \
# 0                               Millau            12145
# 1                                  NaN              NaN
# 2                            Carpiquet            14137
# 3                             Guipavas            29075
# 4                               Embrun            05046
# ...                                ...              ...
# 2174176                     Athis-Mons            91027
# 2174177                        Bourges            18033
# 2174178                   Saint-Pierre            97502
# 2174179  les Éparses de l'océan Indien            98415
# 2174180        Saint-Laurent-du-Maroni            97311
#
#                          EPCI (name)  EPCI (code)  \
# 0        CC de Millau Grands Causses  241200567.0
# 1                                NaN          NaN
# 2                     CU Caen la Mer  200065597.0
# 3                    Brest Métropole  242900314.0
# 4                    CC Serre-Ponçon  200067742.0
# ...                              ...          ...
# 2174176     Métropole du Grand Paris  200054781.0
# 2174177              CA Bourges Plus  241800507.0
# 2174178                          NaN          NaN
# 2174179                          NaN          NaN
# 2174180       CC de l'Ouest Guyanais  249730037.0
#
#                                    department (name)  department (code)  \
# 0                                            Aveyron                 12
# 1                                                NaN                NaN
# 2                                           Calvados                 14
# 3                                          Finistère                 29
# 4                                       Hautes-Alpes                 05
# ...                                              ...                ...
# 2174176                                      Essonne                 91
# 2174177                                         Cher                 18
# 2174178                     Saint-Pierre-et-Miquelon                975
# 2174179  Terres australes et antarctiques françaises                984
# 2174180                                       Guyane                973
#
#                                        region (name)  region (code)  \
# 0                                          Occitanie           76.0
# 1                                                NaN            NaN
# 2                                          Normandie           28.0
# 3                                           Bretagne           53.0
# 4                         Provence-Alpes-Côte d'Azur           93.0
# ...                                              ...            ...
# 2174176                                Île-de-France           11.0
# 2174177                          Centre-Val de Loire           24.0
# 2174178                     Saint-Pierre-et-Miquelon          975.0
# 2174179  Terres australes et antarctiques françaises          984.0
# 2174180                                       Guyane            3.0
#
#          mois_de_l_annee
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 2174176                4
# 2174177                4
# 2174178                4
# 2174179                4
# 2174180                4
#
# [2174181 rows x 82 columns]

# %%
temp.columns
# Out:
# Index(['ID OMM station', 'Date', 'Pression au niveau mer',
#        'Variation de pression en 3 heures', 'Type de tendance barométrique',
#        'Direction du vent moyen 10 mn', 'Vitesse du vent moyen 10 mn',
#        'Température', 'Point de rosée', 'Humidité', 'Visibilité horizontale',
#        'Temps présent', 'Temps passé 1', 'Temps passé 2', 'Nebulosité totale',
#        'Nébulosité  des nuages de l' étage inférieur',
#        'Hauteur de la base des nuages de l'étage inférieur',
#        'Type des nuages de l'étage inférieur',
#        'Type des nuages de l'étage moyen',
#        'Type des nuages de l'étage supérieur', 'Pression station',
#        'Niveau barométrique', 'Géopotentiel',
#        'Variation de pression en 24 heures',
#        'Température minimale sur 12 heures',
#        'Température minimale sur 24 heures',
#        'Température maximale sur 12 heures',
#        'Température maximale sur 24 heures',
#        'Température minimale du sol sur 12 heures',
#        'Méthode de mesure Température du thermomètre mouillé',
#        'Température du thermomètre mouillé',
#        'Rafale sur les 10 dernières minutes', 'Rafales sur une période',
#        'Periode de mesure de la rafale', 'Etat du sol',
#        'Hauteur totale de la couche de neige, glace, autre au sol',
#        'Hauteur de la neige fraîche', 'Periode de mesure de la neige fraiche',
#        'Précipitations dans la dernière heure',
#        'Précipitations dans les 3 dernières heures',
#        'Précipitations dans les 6 dernières heures',
#        'Précipitations dans les 12 dernières heures',
#        'Précipitations dans les 24 dernières heures', 'Phénomène spécial 1',
#        'Phénomène spécial 2', 'Phénomène spécial 3', 'Phénomène spécial 4',
#        'Nébulosité couche nuageuse 1', 'Type nuage 1', 'Hauteur de base 1',
#        'Nébulosité couche nuageuse 2', 'Type nuage 2', 'Hauteur de base 2',
#        'Nébulosité couche nuageuse 3', 'Type nuage 3', 'Hauteur de base 3',
#        'Nébulosité couche nuageuse 4', 'Type nuage 4', 'Hauteur de base 4',
#        'Coordonnees', 'Nom', 'Type de tendance barométrique.1',
#        'Temps passé 1.1', 'Temps présent.1', 'Température (°C)',
#        'Température minimale sur 12 heures (°C)',
#        'Température minimale sur 24 heures (°C)',
#        'Température maximale sur 12 heures (°C)',
#        'Température maximale sur 24 heures (°C)',
#        'Température minimale du sol sur 12 heures (en °C)', 'Latitude',
#        'Longitude', 'Altitude', 'communes (name)', 'communes (code)',
#        'EPCI (name)', 'EPCI (code)', 'department (name)', 'department (code)',
#        'region (name)', 'region (code)', 'mois_de_l_annee'],
#       dtype='object')

# %%
meteo = temp[temp['region (name)']=='Île-de-France']

print(meteo.shape)
meteo.head(3)
# Out:
# (37615, 82)
#     ID OMM station                       Date  Pression au niveau mer  \
# 8             7149  2010-01-05T16:00:00+01:00                100530.0
# 18            7149  2010-01-06T01:00:00+01:00                100360.0
# 77            7149  2010-01-05T01:00:00+01:00                101440.0
#
#     Variation de pression en 3 heures  Type de tendance barométrique  \
# 8                              -210.0                            6.0
# 18                             -100.0                            8.0
# 77                             -150.0                            8.0
#
#     Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  Température  \
# 8                            10.0                          2.6       272.65
# 18                          230.0                          1.0       268.75
# 77                           80.0                          1.0       267.55
#
#     Point de rosée  Humidité  ...  Altitude  communes (name)  communes (code)  \
# 8           268.25      69.0  ...        89       Athis-Mons            91027
# 18          268.05      94.0  ...        89       Athis-Mons            91027
# 77          266.35      90.0  ...        89       Athis-Mons            91027
#
#                  EPCI (name)  EPCI (code)  department (name)  \
# 8   Métropole du Grand Paris  200054781.0            Essonne
# 18  Métropole du Grand Paris  200054781.0            Essonne
# 77  Métropole du Grand Paris  200054781.0            Essonne
#
#     department (code)  region (name)  region (code)  mois_de_l_annee
# 8                  91  Île-de-France           11.0                1
# 18                 91  Île-de-France           11.0                1
# 77                 91  Île-de-France           11.0                1
#
# [3 rows x 82 columns]

# %%
meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37615 entries, 8 to 2174176
# Data columns (total 82 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   ID OMM station                                             37615 non-null  int64
#  1   Date                                                       37615 non-null  object
#  2   Pression au niveau mer                                     37613 non-null  float64
#  3   Variation de pression en 3 heures                          37612 non-null  float64
#  4   Type de tendance barométrique                              37614 non-null  float64
#  5   Direction du vent moyen 10 mn                              37614 non-null  float64
#  6   Vitesse du vent moyen 10 mn                                37614 non-null  float64
#  7   Température                                                37614 non-null  float64
#  8   Point de rosée                                             37614 non-null  float64
#  9   Humidité                                                   37614 non-null  float64
#  10  Visibilité horizontale                                     37613 non-null  float64
#  11  Temps présent                                              37608 non-null  float64
#  12  Temps passé 1                                              35641 non-null  float64
#  13  Temps passé 2                                              35621 non-null  float64
#  14  Nebulosité totale                                          35654 non-null  float64
#  15  Nébulosité  des nuages de l' étage inférieur               35554 non-null  float64
#  16  Hauteur de la base des nuages de l'étage inférieur         31717 non-null  float64
#  17  Type des nuages de l'étage inférieur                       31928 non-null  float64
#  18  Type des nuages de l'étage moyen                           25572 non-null  float64
#  19  Type des nuages de l'étage supérieur                       24010 non-null  float64
#  20  Pression station                                           37614 non-null  float64
#  21  Niveau barométrique                                        0 non-null      float64
#  22  Géopotentiel                                               0 non-null      float64
#  23  Variation de pression en 24 heures                         22983 non-null  float64
#  24  Température minimale sur 12 heures                         9404 non-null   float64
#  25  Température minimale sur 24 heures                         0 non-null      float64
#  26  Température maximale sur 12 heures                         9404 non-null   float64
#  27  Température maximale sur 24 heures                         0 non-null      float64
#  28  Température minimale du sol sur 12 heures                  1829 non-null   float64
#  29  Méthode de mesure Température du thermomètre mouillé       0 non-null      float64
#  30  Température du thermomètre mouillé                         0 non-null      float64
#  31  Rafale sur les 10 dernières minutes                        23181 non-null  float64
#  32  Rafales sur une période                                    37602 non-null  float64
#  33  Periode de mesure de la rafale                             37603 non-null  float64
#  34  Etat du sol                                                24919 non-null  float64
#  35  Hauteur totale de la couche de neige, glace, autre au sol  24969 non-null  float64
#  36  Hauteur de la neige fraîche                                31956 non-null  float64
#  37  Periode de mesure de la neige fraiche                      30201 non-null  float64
#  38  Précipitations dans la dernière heure                      37431 non-null  float64
#  39  Précipitations dans les 3 dernières heures                 37534 non-null  float64
#  40  Précipitations dans les 6 dernières heures                 26581 non-null  float64
#  41  Précipitations dans les 12 dernières heures                26516 non-null  float64
#  42  Précipitations dans les 24 dernières heures                24642 non-null  float64
#  43  Phénomène spécial 1                                        14347 non-null  float64
#  44  Phénomène spécial 2                                        14344 non-null  float64
#  45  Phénomène spécial 3                                        13752 non-null  float64
#  46  Phénomène spécial 4                                        181 non-null    float64
#  47  Nébulosité couche nuageuse 1                               31985 non-null  float64
#  48  Type nuage 1                                               29260 non-null  float64
#  49  Hauteur de base 1                                          31354 non-null  float64
#  50  Nébulosité couche nuageuse 2                               17591 non-null  float64
#  51  Type nuage 2                                               15839 non-null  float64
#  52  Hauteur de base 2                                          17456 non-null  float64
#  53  Nébulosité couche nuageuse 3                               4997 non-null   float64
#  54  Type nuage 3                                               4035 non-null   float64
#  55  Hauteur de base 3                                          4979 non-null   float64
#  56  Nébulosité couche nuageuse 4                               242 non-null    float64
#  57  Type nuage 4                                               491 non-null    float64
#  58  Hauteur de base 4                                          242 non-null    float64
#  59  Coordonnees                                                37615 non-null  object
#  60  Nom                                                        37615 non-null  object
#  61  Type de tendance barométrique.1                            37614 non-null  object
#  62  Temps passé 1.1                                            35641 non-null  object
#  63  Temps présent.1                                            37608 non-null  object
#  64  Température (°C)                                           37614 non-null  float64
#  65  Température minimale sur 12 heures (°C)                    9404 non-null   float64
#  66  Température minimale sur 24 heures (°C)                    0 non-null      float64
#  67  Température maximale sur 12 heures (°C)                    9404 non-null   float64
#  68  Température maximale sur 24 heures (°C)                    0 non-null      float64
#  69  Température minimale du sol sur 12 heures (en °C)          1829 non-null   float64
#  70  Latitude                                                   37615 non-null  float64
#  71  Longitude                                                  37615 non-null  float64
#  72  Altitude                                                   37615 non-null  int64
#  73  communes (name)                                            37615 non-null  object
#  74  communes (code)                                            37615 non-null  object
#  75  EPCI (name)                                                37615 non-null  object
#  76  EPCI (code)                                                37615 non-null  float64
#  77  department (name)                                          37615 non-null  object
#  78  department (code)                                          37615 non-null  object
#  79  region (name)                                              37615 non-null  object
#  80  region (code)                                              37615 non-null  float64
#  81  mois_de_l_annee                                            37615 non-null  int64
# dtypes: float64(67), int64(3), object(12)
# memory usage: 23.8+ MB

# %%
meteo['Date'] = pd.to_datetime(meteo['Date'], utc=True)
# Out:
# /var/folders/bn/wmnlmrqn173_fl00j17x5hqm0000gn/T/ipykernel_20886/3015455840.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meteo['Date'] = pd.to_datetime(meteo['Date'], utc=True)

# %%
meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37615 entries, 8 to 2174176
# Data columns (total 82 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   ID OMM station                                             37615 non-null  int64
#  1   Date                                                       37615 non-null  datetime64[ns, UTC]
#  2   Pression au niveau mer                                     37613 non-null  float64
#  3   Variation de pression en 3 heures                          37612 non-null  float64
#  4   Type de tendance barométrique                              37614 non-null  float64
#  5   Direction du vent moyen 10 mn                              37614 non-null  float64
#  6   Vitesse du vent moyen 10 mn                                37614 non-null  float64
#  7   Température                                                37614 non-null  float64
#  8   Point de rosée                                             37614 non-null  float64
#  9   Humidité                                                   37614 non-null  float64
#  10  Visibilité horizontale                                     37613 non-null  float64
#  11  Temps présent                                              37608 non-null  float64
#  12  Temps passé 1                                              35641 non-null  float64
#  13  Temps passé 2                                              35621 non-null  float64
#  14  Nebulosité totale                                          35654 non-null  float64
#  15  Nébulosité  des nuages de l' étage inférieur               35554 non-null  float64
#  16  Hauteur de la base des nuages de l'étage inférieur         31717 non-null  float64
#  17  Type des nuages de l'étage inférieur                       31928 non-null  float64
#  18  Type des nuages de l'étage moyen                           25572 non-null  float64
#  19  Type des nuages de l'étage supérieur                       24010 non-null  float64
#  20  Pression station                                           37614 non-null  float64
#  21  Niveau barométrique                                        0 non-null      float64
#  22  Géopotentiel                                               0 non-null      float64
#  23  Variation de pression en 24 heures                         22983 non-null  float64
#  24  Température minimale sur 12 heures                         9404 non-null   float64
#  25  Température minimale sur 24 heures                         0 non-null      float64
#  26  Température maximale sur 12 heures                         9404 non-null   float64
#  27  Température maximale sur 24 heures                         0 non-null      float64
#  28  Température minimale du sol sur 12 heures                  1829 non-null   float64
#  29  Méthode de mesure Température du thermomètre mouillé       0 non-null      float64
#  30  Température du thermomètre mouillé                         0 non-null      float64
#  31  Rafale sur les 10 dernières minutes                        23181 non-null  float64
#  32  Rafales sur une période                                    37602 non-null  float64
#  33  Periode de mesure de la rafale                             37603 non-null  float64
#  34  Etat du sol                                                24919 non-null  float64
#  35  Hauteur totale de la couche de neige, glace, autre au sol  24969 non-null  float64
#  36  Hauteur de la neige fraîche                                31956 non-null  float64
#  37  Periode de mesure de la neige fraiche                      30201 non-null  float64
#  38  Précipitations dans la dernière heure                      37431 non-null  float64
#  39  Précipitations dans les 3 dernières heures                 37534 non-null  float64
#  40  Précipitations dans les 6 dernières heures                 26581 non-null  float64
#  41  Précipitations dans les 12 dernières heures                26516 non-null  float64
#  42  Précipitations dans les 24 dernières heures                24642 non-null  float64
#  43  Phénomène spécial 1                                        14347 non-null  float64
#  44  Phénomène spécial 2                                        14344 non-null  float64
#  45  Phénomène spécial 3                                        13752 non-null  float64
#  46  Phénomène spécial 4                                        181 non-null    float64
#  47  Nébulosité couche nuageuse 1                               31985 non-null  float64
#  48  Type nuage 1                                               29260 non-null  float64
#  49  Hauteur de base 1                                          31354 non-null  float64
#  50  Nébulosité couche nuageuse 2                               17591 non-null  float64
#  51  Type nuage 2                                               15839 non-null  float64
#  52  Hauteur de base 2                                          17456 non-null  float64
#  53  Nébulosité couche nuageuse 3                               4997 non-null   float64
#  54  Type nuage 3                                               4035 non-null   float64
#  55  Hauteur de base 3                                          4979 non-null   float64
#  56  Nébulosité couche nuageuse 4                               242 non-null    float64
#  57  Type nuage 4                                               491 non-null    float64
#  58  Hauteur de base 4                                          242 non-null    float64
#  59  Coordonnees                                                37615 non-null  object
#  60  Nom                                                        37615 non-null  object
#  61  Type de tendance barométrique.1                            37614 non-null  object
#  62  Temps passé 1.1                                            35641 non-null  object
#  63  Temps présent.1                                            37608 non-null  object
#  64  Température (°C)                                           37614 non-null  float64
#  65  Température minimale sur 12 heures (°C)                    9404 non-null   float64
#  66  Température minimale sur 24 heures (°C)                    0 non-null      float64
#  67  Température maximale sur 12 heures (°C)                    9404 non-null   float64
#  68  Température maximale sur 24 heures (°C)                    0 non-null      float64
#  69  Température minimale du sol sur 12 heures (en °C)          1829 non-null   float64
#  70  Latitude                                                   37615 non-null  float64
#  71  Longitude                                                  37615 non-null  float64
#  72  Altitude                                                   37615 non-null  int64
#  73  communes (name)                                            37615 non-null  object
#  74  communes (code)                                            37615 non-null  object
#  75  EPCI (name)                                                37615 non-null  object
#  76  EPCI (code)                                                37615 non-null  float64
#  77  department (name)                                          37615 non-null  object
#  78  department (code)                                          37615 non-null  object
#  79  region (name)                                              37615 non-null  object
#  80  region (code)                                              37615 non-null  float64
#  81  mois_de_l_annee                                            37615 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(67), int64(3), object(11)
# memory usage: 23.8+ MB

# %%
meteo.head(5)

tempA = meteo
tempA.head(3)
# Out:
#     ID OMM station                      Date  Pression au niveau mer  \
# 8             7149 2010-01-05 15:00:00+00:00                100530.0
# 18            7149 2010-01-06 00:00:00+00:00                100360.0
# 77            7149 2010-01-05 00:00:00+00:00                101440.0
#
#     Variation de pression en 3 heures  Type de tendance barométrique  \
# 8                              -210.0                            6.0
# 18                             -100.0                            8.0
# 77                             -150.0                            8.0
#
#     Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  Température  \
# 8                            10.0                          2.6       272.65
# 18                          230.0                          1.0       268.75
# 77                           80.0                          1.0       267.55
#
#     Point de rosée  Humidité  ...  Altitude  communes (name)  communes (code)  \
# 8           268.25      69.0  ...        89       Athis-Mons            91027
# 18          268.05      94.0  ...        89       Athis-Mons            91027
# 77          266.35      90.0  ...        89       Athis-Mons            91027
#
#                  EPCI (name)  EPCI (code)  department (name)  \
# 8   Métropole du Grand Paris  200054781.0            Essonne
# 18  Métropole du Grand Paris  200054781.0            Essonne
# 77  Métropole du Grand Paris  200054781.0            Essonne
#
#     department (code)  region (name)  region (code)  mois_de_l_annee
# 8                  91  Île-de-France           11.0                1
# 18                 91  Île-de-France           11.0                1
# 77                 91  Île-de-France           11.0                1
#
# [3 rows x 82 columns]

# %%
tempA.columns
# Out:
# Index(['ID OMM station', 'Date', 'Pression au niveau mer',
#        'Variation de pression en 3 heures', 'Type de tendance barométrique',
#        'Direction du vent moyen 10 mn', 'Vitesse du vent moyen 10 mn',
#        'Température', 'Point de rosée', 'Humidité', 'Visibilité horizontale',
#        'Temps présent', 'Temps passé 1', 'Temps passé 2', 'Nebulosité totale',
#        'Nébulosité  des nuages de l' étage inférieur',
#        'Hauteur de la base des nuages de l'étage inférieur',
#        'Type des nuages de l'étage inférieur',
#        'Type des nuages de l'étage moyen',
#        'Type des nuages de l'étage supérieur', 'Pression station',
#        'Niveau barométrique', 'Géopotentiel',
#        'Variation de pression en 24 heures',
#        'Température minimale sur 12 heures',
#        'Température minimale sur 24 heures',
#        'Température maximale sur 12 heures',
#        'Température maximale sur 24 heures',
#        'Température minimale du sol sur 12 heures',
#        'Méthode de mesure Température du thermomètre mouillé',
#        'Température du thermomètre mouillé',
#        'Rafale sur les 10 dernières minutes', 'Rafales sur une période',
#        'Periode de mesure de la rafale', 'Etat du sol',
#        'Hauteur totale de la couche de neige, glace, autre au sol',
#        'Hauteur de la neige fraîche', 'Periode de mesure de la neige fraiche',
#        'Précipitations dans la dernière heure',
#        'Précipitations dans les 3 dernières heures',
#        'Précipitations dans les 6 dernières heures',
#        'Précipitations dans les 12 dernières heures',
#        'Précipitations dans les 24 dernières heures', 'Phénomène spécial 1',
#        'Phénomène spécial 2', 'Phénomène spécial 3', 'Phénomène spécial 4',
#        'Nébulosité couche nuageuse 1', 'Type nuage 1', 'Hauteur de base 1',
#        'Nébulosité couche nuageuse 2', 'Type nuage 2', 'Hauteur de base 2',
#        'Nébulosité couche nuageuse 3', 'Type nuage 3', 'Hauteur de base 3',
#        'Nébulosité couche nuageuse 4', 'Type nuage 4', 'Hauteur de base 4',
#        'Coordonnees', 'Nom', 'Type de tendance barométrique.1',
#        'Temps passé 1.1', 'Temps présent.1', 'Température (°C)',
#        'Température minimale sur 12 heures (°C)',
#        'Température minimale sur 24 heures (°C)',
#        'Température maximale sur 12 heures (°C)',
#        'Température maximale sur 24 heures (°C)',
#        'Température minimale du sol sur 12 heures (en °C)', 'Latitude',
#        'Longitude', 'Altitude', 'communes (name)', 'communes (code)',
#        'EPCI (name)', 'EPCI (code)', 'department (name)', 'department (code)',
#        'region (name)', 'region (code)', 'mois_de_l_annee'],
#       dtype='object')

# %%
meteo = tempA.drop(
    columns=['ID OMM station', 'Pression au niveau mer',
 'Variation de pression en 3 heures',
 'Type de tendance barométrique',
 'Direction du vent moyen 10 mn', 'Point de rosée','Visibilité horizontale',
 'Temps présent',
 'Temps passé 1',
 'Temps passé 2',
 'Nebulosité totale',
 "Nébulosité  des nuages de l' étage inférieur",
 "Hauteur de la base des nuages de l'étage inférieur",
 "Type des nuages de l'étage inférieur",
 "Type des nuages de l'étage moyen",
 "Type des nuages de l'étage supérieur",
 'Pression station',
 'Niveau barométrique',
 'Géopotentiel',
 'Variation de pression en 24 heures',
 'Température minimale sur 12 heures','Température minimale sur 24 heures',
       'Température maximale sur 12 heures',
       'Température maximale sur 24 heures',
       'Température minimale du sol sur 12 heures',
       'Méthode de mesure Température du thermomètre mouillé',
       'Température du thermomètre mouillé',
       'Rafale sur les 10 dernières minutes', 'Rafales sur une période',
       'Periode de mesure de la rafale', 'Etat du sol',
       'Hauteur totale de la couche de neige, glace, autre au sol',
       'Hauteur de la neige fraîche', 'Periode de mesure de la neige fraiche',
       'Précipitations dans la dernière heure',
       'Précipitations dans les 3 dernières heures',
       'Précipitations dans les 6 dernières heures',
       'Précipitations dans les 12 dernières heures',
       'Précipitations dans les 24 dernières heures', 'Phénomène spécial 1',
       'Phénomène spécial 2', 'Phénomène spécial 3', 'Phénomène spécial 4',
       'Nébulosité couche nuageuse 1', 'Type nuage 1', 'Hauteur de base 1',
       'Nébulosité couche nuageuse 2', 'Type nuage 2', 'Hauteur de base 2',
       'Nébulosité couche nuageuse 3', 'Type nuage 3', 'Hauteur de base 3',
       'Nébulosité couche nuageuse 4', 'Type nuage 4', 'Hauteur de base 4',
       'Coordonnees', 'Nom', 'Type de tendance barométrique.1',
       'Temps passé 1.1', 'Temps présent.1', 'Température minimale sur 12 heures (°C)',
       'Température minimale sur 24 heures (°C)',
       'Température maximale sur 12 heures (°C)',
       'Température maximale sur 24 heures (°C)',
       'Température minimale du sol sur 12 heures (en °C)'
]
)

# %%
meteo.head(3)
# Out:
#                         Date  Vitesse du vent moyen 10 mn  Température  \
# 8  2010-01-05 15:00:00+00:00                          2.6       272.65
# 18 2010-01-06 00:00:00+00:00                          1.0       268.75
# 77 2010-01-05 00:00:00+00:00                          1.0       267.55
#
#     Humidité  Température (°C)   Latitude  Longitude  Altitude  \
# 8       69.0              -0.5  48.716833   2.384333        89
# 18      94.0              -4.4  48.716833   2.384333        89
# 77      90.0              -5.6  48.716833   2.384333        89
#
#    communes (name) communes (code)               EPCI (name)  EPCI (code)  \
# 8       Athis-Mons           91027  Métropole du Grand Paris  200054781.0
# 18      Athis-Mons           91027  Métropole du Grand Paris  200054781.0
# 77      Athis-Mons           91027  Métropole du Grand Paris  200054781.0
#
#    department (name) department (code)  region (name)  region (code)  \
# 8            Essonne                91  Île-de-France           11.0
# 18           Essonne                91  Île-de-France           11.0
# 77           Essonne                91  Île-de-France           11.0
#
#     mois_de_l_annee
# 8                 1
# 18                1
# 77                1

# %%
meteo['Date'] = pd.to_datetime(meteo['Date'], utc=True)
meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37615 entries, 8 to 2174176
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         37615 non-null  datetime64[ns, UTC]
#  1   Vitesse du vent moyen 10 mn  37614 non-null  float64
#  2   Température                  37614 non-null  float64
#  3   Humidité                     37614 non-null  float64
#  4   Température (°C)             37614 non-null  float64
#  5   Latitude                     37615 non-null  float64
#  6   Longitude                    37615 non-null  float64
#  7   Altitude                     37615 non-null  int64
#  8   communes (name)              37615 non-null  object
#  9   communes (code)              37615 non-null  object
#  10  EPCI (name)                  37615 non-null  object
#  11  EPCI (code)                  37615 non-null  float64
#  12  department (name)            37615 non-null  object
#  13  department (code)            37615 non-null  object
#  14  region (name)                37615 non-null  object
#  15  region (code)                37615 non-null  float64
#  16  mois_de_l_annee              37615 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(8), int64(2), object(6)
# memory usage: 5.2+ MB

# %%
import datetime

meteo2022 = meteo[meteo["Date"]> "2021-12-31 23:59:59+01:00"]

print(meteo2022.shape)
meteo2022.head(2)
# Out:
# (2607, 17)
#                              Date  Vitesse du vent moyen 10 mn  Température  \
# 1402586 2022-01-02 03:00:00+00:00                          3.2       282.35
# 1402596 2022-01-02 21:00:00+00:00                          7.0       285.35
#
#          Humidité  Température (°C)   Latitude  Longitude  Altitude  \
# 1402586      85.0               9.2  48.716833   2.384333        89
# 1402596      79.0              12.2  48.716833   2.384333        89
#
#         communes (name) communes (code)               EPCI (name)  \
# 1402586      Athis-Mons           91027  Métropole du Grand Paris
# 1402596      Athis-Mons           91027  Métropole du Grand Paris
#
#          EPCI (code) department (name) department (code)  region (name)  \
# 1402586  200054781.0           Essonne                91  Île-de-France
# 1402596  200054781.0           Essonne                91  Île-de-France
#
#          region (code)  mois_de_l_annee
# 1402586           11.0                1
# 1402596           11.0                1

# %%
meteo2022.columns
# Out:
# Index(['Date', 'Vitesse du vent moyen 10 mn', 'Température', 'Humidité',
#        'Température (°C)', 'Latitude', 'Longitude', 'Altitude',
#        'communes (name)', 'communes (code)', 'EPCI (name)', 'EPCI (code)',
#        'department (name)', 'department (code)', 'region (name)',
#        'region (code)', 'mois_de_l_annee'],
#       dtype='object')

# %%
meteo2022 = meteo2022.drop(
    columns=['Latitude', 'Longitude', 'Altitude',
       'communes (name)', 'communes (code)', 'EPCI (code)',
       'department (name)', 'department (code)', 'region (name)',
       'region (code)', 'mois_de_l_annee']
)

# %%
# Out:
# 2607

# %%
meteo2022["id_meteo"]=range(1,meteo2022.shape[0]+1)

# %%
meteo2022 = meteo2022[["id_meteo", "Date", "EPCI (name)","Vitesse du vent moyen 10 mn","Humidité","Température (°C)"]]
meteo2022
# Out:
#          id_meteo                      Date               EPCI (name)  \
# 1402586         1 2022-01-02 03:00:00+00:00  Métropole du Grand Paris
# 1402596         2 2022-01-02 21:00:00+00:00  Métropole du Grand Paris
# 1402611         3 2022-01-03 12:00:00+00:00  Métropole du Grand Paris
# 1405107         4 2022-01-04 18:00:00+00:00  Métropole du Grand Paris
# 1405164         5 2022-01-07 15:00:00+00:00  Métropole du Grand Paris
# ...           ...                       ...                       ...
# 2166876      2603 2022-01-16 21:00:00+00:00  Métropole du Grand Paris
# 2166954      2604 2022-02-08 03:00:00+00:00  Métropole du Grand Paris
# 2167277      2605 2022-01-21 12:00:00+00:00  Métropole du Grand Paris
# 2167300      2606 2022-01-22 21:00:00+00:00  Métropole du Grand Paris
# 2167323      2607 2022-01-24 06:00:00+00:00  Métropole du Grand Paris
#
#          Vitesse du vent moyen 10 mn  Humidité  Température (°C)
# 1402586                          3.2      85.0               9.2
# 1402596                          7.0      79.0              12.2
# 1402611                          5.8      84.0              11.8
# 1405107                          6.1      74.0               8.3
# 1405164                          7.1      68.0               7.7
# ...                              ...       ...               ...
# 2166876                          4.0     100.0               3.9
# 2166954                          2.0      83.0               5.5
# 2167277                          2.8      80.0               4.9
# 2167300                          1.8      86.0               4.5
# 2167323                          2.2      94.0               0.1
#
# [2607 rows x 6 columns]

# %%
meteo2022.to_csv('meteoParis2022.csv', index=False, encoding='utf-8')
